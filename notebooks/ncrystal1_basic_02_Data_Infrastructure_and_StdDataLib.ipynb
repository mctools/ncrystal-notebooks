# %% [markdown]
# # NCrystal data infrastructure and standard data library
#
# In this notebook we will discuss the NCrystal data library of predefined materials, as well as the general infrastructure for such data.

# %% [markdown]
# ## Preamble
# Install dependencies and prepare plots. Feel free to edit as you wish:

# %%
#By default we only do pip installs on Google Colab, but you
#can set the variable in the next line to True if you need it:
always_do_pip_installs = False
try:
    import google.colab as google_colab
except ModuleNotFoundError:
    google_colab=None#not on google colab
if always_do_pip_installs or google_colab:
    # %pip -q install ncrystal[plot] ipympl
#enable inline and interactive matplotlib plots:
if google_colab:
    google_colab.output.enable_custom_widget_manager()
    # %matplotlib inline
else:
    # %matplotlib ipympl
import matplotlib
matplotlib.rcParams.update({"figure.autolayout": True})
#always import NCrystal:
import NCrystal as NC
assert NC.version_num >=  4000000, "too old NCrystal found"
NC.test() #< quick unit test that installation works
# Out:
# Tests completed succesfully

# %% [markdown]
# ## The NCrystal standard data library
# The first and foremost source, is of course materials pre-created by other scientists (be it NCrystal developers or your colleagues). Any complete NCrystal installation should include the standard data library ("stdlib") of NCMAT files. For the ~latest NCrystal release, it can be browsed online at the wiki: https://github.com/mctools/ncrystal/wiki/Data-library
#
# So assuming you find the material (say, zirconia) you were looking for on that page, you can as usual proceed to have a look at it:

# %%
import NCrystal.plot as ncplot
ncplot.plot_xsect('ZrO2_sg137_Zirconia.ncmat')#remember: room temperature by default
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Physical (on-disk) and virtual files (in-memory) data
# Depending on your installation of NCrystal, the "files" in the standard data library might reside as physical files on-disk, or they might be "baked in" to the NCrystal binary library as virtual files. It should not matter to you. If you wish to get the raw content of a file, you can do so with the `createTextData` function (or via `nctool --extract` on the commandline):

# %%
td = NC.createTextData('stdlib::ZrO2_sg137_Zirconia.ncmat')
# or this way, to prevent accidentally picking up a file you downloaded,
# edited, and left lying around in your working directory:
# td = NC.createTextData('stdlib::ZrO2_sg137_Zirconia.ncmat')

# %% [markdown]
# Note that the `stdlib::` part is optional. By specifying it, we avoid accidentally picking up a file of the same name that you might have previously downloaded, edited, and left lying around in your working directory. Anyway, what can we do with such a `TextData` object?:

# %%
help(td)
# Out:
# Help on TextData in module NCrystal.core object:
#
# class TextData(builtins.object)
#  |  TextData(name)
#  |
#  |  Text data accessible line by line, with associated meta-data. This always
#  |  include a UID (useful for comparison and downstream caching purposes) and
#  |  the data type (e.g. "ncmat"). Optionally available is the last known
#  |  on-disk path to a file with the same content, which might be useful in
#  |  case the data needs to be passed to 3rd party software which can only
#  |  work with physical files.
#  |
#  |  Text data objects are easily line-iterable, easily providing lines
#  |  (without newline characters): for( auto& line : mytextdata ) {...}.  Of
#  |  course, the raw underlying data buffer can also be accessed if needed.
#  |
#  |  The raw data must be ASCII or UTF-8 text, with line endings \n=CR=0x0A
#  |  (Unix) or \r\n=LF+CR=0x0D0A (Windows/DOS). Other encodings might work
#  |  only if 0x00, 0x0A, 0x0D bytes do not occur in them outside of line
#  |  endings.
#  |
#  |  Notice that ancient pre-OSX Mac line-endings \r=LF=0x0D are not
#  |  supported, and iterators will actually throw an error upon encountering
#  |  them. This is done on purpose, since files with \r on unix might hide
#  |  content when inspected in a terminal can be either confusing, a potential
#  |  security issue, or both.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name)
#  |      create TextData object based on string (same as using createTextData(name))
#  |
#  |  __iter__(self)
#  |      Line-iteration, yielding lines without terminating newline characters
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  dump(self)
#  |      Convenience method which prints the contents.
#  |
#  |  dump_str(self)
#  |      Alias which simply returns .rawData (this method exists exclusively
#  |      for API consistency).
#  |
#  |  load(self)
#  |      Convenience method which loads the TextData with the directLoad(..)
#  |      function and returns the resulting LoadedMaterial object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  dataSourceName
#  |      Data source name. This might for instance be a filename.
#  |
#  |  dataType
#  |      Data type ("ncmat", "lau", ...).
#  |
#  |  lastKnownOnDiskLocation
#  |      Last known on-disk location (returns None if unavailable). Note that there
#  |      is no guarantee against the file having been removed or modified since the
#  |      TextData object was created.
#  |
#  |  rawData
#  |      Raw access to underlying data.
#  |
#  |  uid
#  |      Unique identifier. Objects only have identical UID if all contents and
#  |      metadata are identical.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
print(td.dataSourceName)
print(td.lastKnownOnDiskLocation)#will be None if file does not exist on-disk
print(td.dataType)
print('-- contents: --')
print(td.rawData)
# Out:
# ZrO2_sg137_Zirconia.ncmat
# None
# ncmat
# -- contents: --
# NCMAT v5
# #
# # Zirconium dioxide (ZrO2, Zirconia, tetragonal, SG-137 / P4_2/nmc))
# #
# # Under usual conditions this phase exists from 1443K to 2643K.
# #
# # Structure converted with ncrystal_onlinedb2ncmat from:
# #
# #    "Simultaneous Structure and Size-Strain Refinement by the Rietveld Method"
# #    Lutterotti, L. and Scardi, P. (1990)
# #    DOI: https://dx.doi.org/10.1107/S0021889890002382
# #    Crystallography Open Database entry 2300612
# #    https://www.crystallography.net/cod/2300612.html
# #
# # This crystal structure is also compatible with structure obtained from:
# #
# #   https://www.crystallography.net/cod/1526427.html
# #   https://www.crystallography.net/cod/1539831.html
# #   https://materialsproject.org/materials/mp-2574
# #
# # The VDOS curves were calculated using Phonopy[1] input files from[2] and
# # OCLIMAX[3] software by Kemal Ramic from ESS Spallation Physics group.
# #
# # References:
# #  [1]: "First principles phonon calculations in materials science",
# #        Atsushi Togo and Isao Tanaka, Scr. Mater., 108, 1-5 (2015)
# #  [2]: Kyoto University database of phonon calculations.
# #       Files for ZrO2 taken from:
# #       http://phonondb.mtl.kyoto-u.ac.jp/ph20180417/d002/mp-2574.html
# #  [3]: Cheng, Y. Q.; Kolesnikov, A. I.; Ramirez-Cuesta, A. J., "Calculation
# #       of the Thermal Neutron Scattering Cross-Section of Solids Using OCLIMAX".
# #       Journal of Chemical Theory and Computation 2020, 16 (8), 5212-5217.
# #
# @CELL
#   lengths 3.5961 !! 5.177
#   angles 90 90 90
# @SPACEGROUP
#   137
# @ATOMPOSITIONS
#   Zr   0   0   0
#   Zr 1/2 1/2 1/2
#   O  1/2   0 .797
#   O    0 1/2 .203
#   O    0 1/2 .703
#   O  1/2   0 .297
# @DYNINFO
#   element  Zr
#   fraction 1/3
#   type     vdos
#   vdos_egrid 0.0114996 0.0900802
#   vdos_density .237227 .306107 .362116 .383859 .474569 .597687 .710741 .846905
#     .939633 .91798 .967135 1 .914285 .85479 .736873 .615481 .623821 .598351
#     .516876 .527455 .637917 .688934 .626478 .587678 .600324 .58561 .585443
#     .547321 .498895 .44565 .355129 .283965 .264113 .275858 .278968 .275977
#     .256882 .240403 .277633 .347025 .388867 .405581 .428175 .470303 .50345
#     .532972 .531345 .508647 .522598 .534681 .541043 .569022 .539561 .469029
#     .396163 .327178 .271278 .253991 .302235 .33355 .300344 .237858 .193874
#     .167236 .137171 .124905 .130496 .12118 .0944805 .0792457 .0789794 .0777843
#     .0733443 .0680001 .0619241 .0589567 .0545217 .0453814 .0365866 .0314068
#     .0312286 .0352567 .0382659 .0365926 .0330367 .0293194 .0269855 .0303226
#     .0363794 .0394606 .0406604 .0414522 .040979 .0431091 .0492428 .0540246
#     .0554283 .059739 .0709595 .0856728 .0999636 .114618 .125948 .129414 .129875
#     .133653 .136004 .133805 .127486 .114636 .0932491 .0707687 .0539422 .0435656
#     .037577 .0342889 .0318958 .0293612 .0286136 .0301386 .0308893 .0302414
#     .0291539 .0268285 .0237773 .0216009 .0212778 .0225385 .024122 .0253256
#     .0263754 .0276663 .0290807 .0299962 .0294532 .0278485 .026001 .0239389
#     .0212121 .019028 .0190717 .0206949 .0221279 .0224774 .0220641 .0215955
#     .0216723 .0222042 .0228431 .0243563 .0272652 .0305645 .03183 .0294584
#     .0251157 .0209091 .0186662 .0184368 .0184885 .0180746 .0176527 .0171574
#     .0160478 .0145693 .01304 .0116485 .0109916 .0108726 .0104633 .00948994
#     .00848812 .00807803 .00840005 .00910394 .00969167 .00967986 .00914515
#     .00889947 .0098311 .0122783 .014989 .0164116 .0164255 .0157091 .0156904
#     .0174728 .0212509 .0270408 .0337541 .0389376 .0396324 .0358773 .0299913
#     .0246581 .0214012 .0200036 .0200995 .0202484 .0190602 .0161491 .0118961
#     .00759972 .00418573 .00195933 .000759269 0
# @DYNINFO
#   element  O
#   fraction 2/3
#   type     vdos
#   vdos_egrid 0.0114996 0.0900802
#   vdos_density .0547354 .0649554 .0828119 .103028 .134183 .163853 .207073
#     .252097 .260567 .22611 .202022 .184401 .145947 .11605 .0926878 .0881817
#     .104533 .130895 .122379 .126588 .160186 .228391 .288221 .28666 .274381
#     .279514 .290005 .303522 .334804 .321243 .271417 .232976 .228736 .217776
#     .186826 .182535 .211084 .253188 .285506 .328722 .385521 .428907 .447691
#     .455947 .424289 .390322 .412907 .469366 .512007 .489424 .438868 .414746
#     .39378 .388723 .398092 .378914 .358902 .386086 .446534 .465153 .430381
#     .389867 .409565 .425275 .360069 .328376 .381449 .385447 .341034 .376932
#     .456291 .461075 .40779 .37239 .375424 .4067 .401159 .339687 .277667 .248378
#     .262713 .312582 .349715 .326847 .272983 .230076 .216299 .246842 .287085
#     .289156 .268371 .261874 .26688 .282139 .306601 .31678 .307089 .323206
#     .388041 .4555 .495269 .527988 .550332 .561952 .58277 .609392 .621714 .619323
#     .61576 .619684 .616707 .579746 .502228 .422153 .373789 .352979 .335833
#     .319574 .321097 .339469 .351866 .358251 .358278 .331321 .28997 .265721
#     .273917 .305034 .332232 .3447 .356781 .382354 .413885 .430259 .424334
#     .420552 .433711 .442373 .431196 .426356 .454709 .498875 .531849 .547163
#     .548579 .546675 .561814 .609989 .685637 .787558 .895619 .957874 .947002
#     .866096 .769375 .693833 .660724 .666038 .67255 .657144 .614804 .546184
#     .466427 .403917 .362049 .321299 .287064 .26295 .236012 .204908 .186107
#     .189181 .212832 .244656 .266472 .256337 .213283 .162048 .131957 .134395
#     .150258 .163593 .172595 .188372 .226792 .308162 .442186 .632444 .839474
#     .986144 1 .904685 .778801 .681867 .627223 .591624 .557434 .509764 .432612
#     .329061 .215591 .119976 .0572081 .0232844 .00808906 0

# %% [markdown]
# Similarly, when you yourself need to add a new NCMAT file, you do not actually have to write a physical file into your filesystem (unless you need the file to persist after your current process is done of course). You can instead simply register the associated data as a physical file in the currently running process:

# %%
a_string_with_ncmat_data="""NCMAT v7
#Don't use this material for anything
@DENSITY
  1.2345 g_per_cm3
@DYNINFO
  element  C
  fraction 1
  type     freegas
"""
NC.registerInMemoryFileData('silly_carbon.ncmat',a_string_with_ncmat_data)

# %%
print(NC.createTextData('silly_carbon.ncmat').rawData)
# Out:
# NCMAT v7
# #Don't use this material for anything
# @DENSITY
#   1.2345 g_per_cm3
# @DYNINFO
#   element  C
#   fraction 1
#   type     freegas

# %%
ncplot.plot_xsect('silly_carbon.ncmat;temp=200K',mode='ekin')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Of course, if all you wanted was to quickly plot the cross sections, you didn't need to register the file and invent a name for it. You could either do:

# %%
mat_silly=NC.load(a_string_with_ncmat_data)
mat_silly.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Or, if you really didn't need to use the material for anything else than this plot:

# %%
ncplot.plot_xsect(a_string_with_ncmat_data)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### NCrystal data source infrastructure
# As we are starting to see, the NCrystal infrastructure which serves up data files based on "filenames" in cfg-strings is rather flexible. The `NCrystal.datasrc` module contain many functions which can be used to fine-tune this. For instance, if you keep your own edition to a data-library in some local folder, you can add that folder to the NCrystal search path. You can either do this by setting the `NCRYSTAL_DATA_PATH` variable (*before* loading NCrystal!), which can contain multiple directories separated by semi-colons in the usual unix fashion. Or you can add a directory to this search path dynamically:

# %%
import pathlib
extra_data_dir = pathlib.Path('./myextradatafiles/')
extra_data_dir.mkdir(exist_ok=True)
( extra_data_dir / 'my_extra_material.ncmat' ).write_text(a_string_with_ncmat_data)
# Out:
# 129

# %%
# !ls ./myextradatafiles
# Out:
# my_extra_material.ncmat

# %%
import NCrystal.datasrc as ncdatasrc
ncdatasrc.addCustomSearchDirectory(extra_data_dir)
td = NC.createTextData('my_extra_material.ncmat')
print(td.dataSourceName)
print(td.lastKnownOnDiskLocation)#will be None if file is virtual (but it won't be in this case)
print(td.dataType)
print('-- contents: --')
print(td.rawData)
# Out:
# my_extra_material.ncmat
# /some/where/myextradatafiles/my_extra_material.ncmat
# ncmat
# -- contents: --
# NCMAT v7
# #Don't use this material for anything
# @DENSITY
#   1.2345 g_per_cm3
# @DYNINFO
#   element  C
#   fraction 1
#   type     freegas

# %% [markdown]
# We have already seen how you can browse available data files via the command line with `nctool -b` or `nctool --browse`, but you can of course also do so from Python:

# %%
NC.browseFiles(dump=True)
# Out:
# ==> 1 file from "relpath" (/some/where, priority=140):
#     myextradatafiles/my_extra_material.ncmat
# ==> 1 file from "virtual" (virtual, priority=130):
#     silly_carbon.ncmat
# ==> 132 files from "stdlib" (stdlib, priority=120):
#     AcrylicGlass_C5O2H8.ncmat
#     AgBr_sg225_SilverBromide.ncmat
#     Ag_sg225.ncmat
#     Al2O3_sg167_Corundum.ncmat
#     Al4C3_sg166_AluminiumCarbide.ncmat
#     AlN_sg186_AluminumNitride.ncmat
#     Al_sg225.ncmat
#     Ar_Gas_STP.ncmat
#     Au_sg225.ncmat
#     BaF2_sg225_BariumFluoride.ncmat
#     BaO_sg225_BariumOxide.ncmat
#     Ba_sg229.ncmat
#     Be3N2_sg206_BerylliumNitride.ncmat
#     BeF2_sg152_Beryllium_Fluoride.ncmat
#     BeO_sg186.ncmat
#     Be_sg194.ncmat
#     Bi_sg166.ncmat
#     C_sg194_pyrolytic_graphite.ncmat
#     C_sg227_Diamond.ncmat
#     CaCO3_sg62_Aragonite.ncmat
#     CaF2_sg225_CalciumFlouride.ncmat
#     CaH2_sg62_CalciumHydride.ncmat
#     CaO2H2_sg164_CalciumHydroxide.ncmat
#     CaO_sg225_CalciumOxide.ncmat
#     CaSiO3_sg2_Wollastonite.ncmat
#     Ca_sg225.ncmat
#     Ca_sg229_Calcium-gamma.ncmat
#     CeO2_sg225_CeriumOxide.ncmat
#     Cr_sg229.ncmat
#     Cu2O_sg224_Cuprite.ncmat
#     Cu_sg225.ncmat
#     Dy2O3_sg206_DysprosiumOxide.ncmat
#     Epoxy_Araldite506_C18H20O3.ncmat
#     Fe_sg225_Iron-gamma.ncmat
#     Fe_sg229_Iron-alpha.ncmat
#     GaN_sg186_GalliumNitride.ncmat
#     GaSe_sg194_GalliumSelenide.ncmat
#     Ge3Bi4O12_sg220_BismuthGermanate.ncmat
#     Ge_sg227.ncmat
#     He_Gas_STP.ncmat
#     HfO2_sg14_HafniumOxide.ncmat
#     Ho2O3_sg206_HolmiumOxide.ncmat
#     KBr_sg225_PotassiumBromide.ncmat
#     KF_sg225_PotassiumFlouride.ncmat
#     KOH_sg4_PotassiumHydroxide.ncmat
#     K_sg229.ncmat
#     Kapton_C22H10N2O5.ncmat
#     Kr_Gas_STP.ncmat
#     LaBr3_sg176_LanthanumBromide.ncmat
#     Li2O_sg225_LithiumOxide.ncmat
#     Li3N_sg191_LithiumNitride.ncmat
#     LiF_sg225_LithiumFlouride.ncmat
#     LiH_sg225_LithiumHydride.ncmat
#     LiquidHeavyWaterD2O_T293.6K.ncmat
#     LiquidWaterH2O_T293.6K.ncmat
#     Lu2O3_sg206_LutetiumOxide.ncmat
#     Lu2SiO5_sg15.ncmat
#     Mg2SiO4_sg62_MagnesiumSilicate.ncmat
#     MgAl2O4_sg227_MAS.ncmat
#     MgCO3_sg167_MagnesiumCarbonate.ncmat
#     MgD2_sg136_MagnesiumDeuteride.ncmat
#     MgF2_sg136_MagnesiumFlouride.ncmat
#     MgH2_sg136_MagnesiumHydride.ncmat
#     MgO2H2_sg164_MagnesiumHydroxide.ncmat
#     MgO_sg225_Periclase.ncmat
#     Mg_sg194.ncmat
#     Mo_sg229.ncmat
#     Na4Si3Al3O12Cl_sg218_Sodalite.ncmat
#     NaBr_sg225_SodiumBromide.ncmat
#     NaCl_sg225_SodiumChloride.ncmat
#     NaF_sg225_SodiumFlouride.ncmat
#     NaI_sg225_SodiumIodide.ncmat
#     Na_sg229.ncmat
#     Nb_sg229.ncmat
#     Ne_Gas_STP.ncmat
#     Ni_sg225.ncmat
#     Nylon11_C11H21NO.ncmat
#     Nylon12_C12H23NO.ncmat
#     Nylon610_C16H30N2O2.ncmat
#     Nylon66or6_C12H22N2O2.ncmat
#     PEEK_C19H12O3.ncmat
#     PVC_C2H3Cl.ncmat
#     PbF2-beta_sg225_BetaLeadFlouride.ncmat
#     PbO-alpha_sg129_Litharge.ncmat
#     PbO-beta_sg57_Massicot.ncmat
#     PbS_sg225_LeadSulfide.ncmat
#     Pb_sg225.ncmat
#     Pd_sg225.ncmat
#     Polycarbonate_C16O3H14.ncmat
#     Polyester_C10H8O4.ncmat
#     Polyethylene_CH2.ncmat
#     Polylactide_C3H4O2.ncmat
#     Polypropylene_C3H6.ncmat
#     Polystyrene_C8H8.ncmat
#     Pt_sg225.ncmat
#     Rb_sg229.ncmat
#     Rubber_C5H8.ncmat
#     Sc_sg194.ncmat
#     SiC-beta_sg216_BetaSiliconCarbide.ncmat
#     SiO2-alpha_sg154_AlphaQuartz.ncmat
#     SiO2-beta_sg180_BetaQuartz.ncmat
#     Si_sg227.ncmat
#     Sn_sg141.ncmat
#     SrF2_sg225_StrontiumFluoride.ncmat
#     SrH2_sg62_StrontiumHydride.ncmat
#     Sr_sg225.ncmat
#     Th3N4_sg166_ThoriumNitride.ncmat
#     ThO2_sg225_ThoriumDioxide.ncmat
#     Th_sg225.ncmat
#     TiO2_sg136_Rutile.ncmat
#     TiO2_sg141_Anatase.ncmat
#     Ti_sg194.ncmat
#     TlBr_sg221_ThaliumBromide.ncmat
#     Tm2O3_sg206_ThuliumOxide.ncmat
#     UF6_sg62_UraniumHexaflouride.ncmat
#     UO2_sg225_UraniumDioxide.ncmat
#     V_sg229.ncmat
#     W_sg229.ncmat
#     Xe_Gas_STP.ncmat
#     Y2O3_sg206_Yttrium_Oxide.ncmat
#     Y2SiO5_sg15_YSO.ncmat
#     Y3Al5O12_sg230_YAG.ncmat
#     Y_sg194.ncmat
#     ZnF2_sg136_ZincFlouride.ncmat
#     ZnO_sg186_ZincOxide.ncmat
#     ZnS_sg216_Sphalerite.ncmat
#     Zn_sg194.ncmat
#     ZrF4-beta_sg84.ncmat
#     ZrO2_sg137_Zirconia.ncmat
#     ZrO2_sg14_Zirconia.ncmat
#     Zr_sg194.ncmat
#     void.ncmat
# ==> 1 file from "customdirs" (/some/where/myextradatafiles, priority=111):
#     my_extra_material.ncmat
# ==> 4 files from "freegas" (examples of on-demand unstructured materials, priority=OnlyOnExplicitRequest):
#     freegas::Ar/2.5e-5perAa3
#     freegas::CF4/3.72kgm3
#     freegas::CO2/1.98kgm3
#     freegas::He/0.17kgm3/He_is_He3
# ==> 9 files from "gasmix" (examples of on-demand gas mixtures, priority=OnlyOnExplicitRequest):
#     gasmix::0.72xCO2+0.28xAr/massfractions/1.5atm/250K
#     gasmix::0.7xCO2+0.3xAr/0.001relhumidity
#     gasmix::0.7xCO2+0.3xAr/1.5atm/250K
#     gasmix::BF3/2atm/25C/B_is_0.95_B10_0.05_B11
#     gasmix::CO2
#     gasmix::He/1.64kgm3
#     gasmix::He/10bar
#     gasmix::air
#     gasmix::air/-10C/0.8atm/0.30relhumidity
# ==> 6 files from "solid" (examples of on-demand unstructured materials, priority=OnlyOnExplicitRequest):
#     solid::Al2O3/4gcm3
#     solid::Al2O3/4gcm3/TDebye750K_Al/TDebye1000K_O
#     solid::Al2O3/4gcm3/TDebye900K
#     solid::B4C/2.52gcm3/B_is_0.95_B10_0.05_B11
#     solid::CH2/1gcm3
#     solid::Gd2O3/7.07gcm3

# %% [markdown]
# ## Atom data
# NCrystal obviously contains an internal database of scattering lengths, cross sections and masses, of a large number of natural elements and specific isotopes. You can access this database directly if needed:

# %%
NC.atomDB('Al')
# Out:
# Al(cohSL=3.449fm cohXS=1.49485barn incXS=0.0082barn absXS=0.231barn mass=26.9815amu Z=13)

# %%
NC.atomDB('He3')
# Out:
# He3(cohSL=5.74fm cohXS=4.14032barn incXS=1.6barn absXS=5333barn mass=3.01603amu Z=2 A=3)

# %% [markdown]
# You can access the data programatically, and as always you can find inline help:

# %%
data_H = NC.atomDB('H')
data_D = NC.atomDB('D')
print(data_H.coherentScatLen())
print(data_D.coherentScatLen())
help(data_H)
# Out:
# -0.3739
# 0.6671
# Help on AtomData in module NCrystal.core object:
#
# class AtomData(RCBase)
#  |  AtomData(rawobj)
#  |
#  |  Class providing physical constants related to a particular mix of
#  |  isotopes. This can be used to represent elements (i.e. all isotopes having
#  |  same Z) in either natural or enriched form, but can also be used to
#  |  represent atoms in doped crystals. E.g. if a small fraction (0.1%) of
#  |  Cr-ions replace some Al-ions in a Al2O3 lattice, the AtomData could
#  |  represent a mix of 0.1% Cr and 99.9% Al.
#  |
#  |  Method resolution order:
#  |      AtomData
#  |      RCBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  A(self)
#  |      Number of nucleons per nuclei (0 if not well defined or natural element).
#  |
#  |  Z(self)
#  |      Number of protons per nuclei (0 if not well defined).
#  |
#  |  __init__(self, rawobj)
#  |      internal usage only
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  averageMassAMU(self)
#  |      Atomic mass in Daltons (averaged appropriately over constituents)
#  |
#  |  captureXS(self)
#  |      Absorption cross section in barn
#  |
#  |  coherentScatLen(self)
#  |      Coherent scattering length in sqrt(barn)=10fm
#  |
#  |  coherentScatLenFM(self)
#  |      Coherent scattering length in fm
#  |
#  |  coherentXS(self)
#  |      Bound coherent cross section in barn. Same as 4*pi*coherentScatLen()**2
#  |
#  |  description(self, includeValues=True)
#  |      Returns description of material as a string, with or without values.
#  |
#  |  displayLabel(self)
#  |      Short label which unique identifies an atom role within a particular material.
#  |
#  |  elementName(self)
#  |      If Z()!=0, this returns the corresponding element name ('H', 'He', ...).
#  |      Returns empty string when Z() is 0.
#  |
#  |  freeCoherentXS(self)
#  |      Free coherent cross section in barn.
#  |
#  |  freeIncoherentXS(self)
#  |      Free incoherent cross section in barn.
#  |
#  |  freeScatteringXS(self)
#  |      Free scattering cross section in barn (same as freeCoherentXS()+freeIncoherentXS())
#  |
#  |  getAllComponents(self)
#  |      Get list of all components
#  |
#  |  getComponent(self, icomponent)
#  |      Get component in a mixture
#  |
#  |  incoherentXS(self)
#  |      Bound incoherent cross section in barn
#  |
#  |  isComposite(self)
#  |      Composite definition. See nComponents(), getComponent() and components property
#  |
#  |  isElement(self)
#  |      If number of protons per nuclei is well defined. This is true for natural
#  |      elements, single isotopes, and composites where all components
#  |      have the same number of protons per nuclei.
#  |
#  |  isNaturalElement(self)
#  |      Natural element with no composition.
#  |
#  |  isSingleIsotope(self)
#  |      Single isotope with no composition.
#  |
#  |  isTopLevel(self)
#  |      Whether or not AtomData appears directly on an Info object. If not,
#  |      it will most likely either be a component (direct or indirect) of a top
#  |      level AtomData object, or be taken from the composition list of a
#  |      multi-phase object.
#  |
#  |  nComponents(self)
#  |      Number of sub-components in a mixture
#  |
#  |  scatteringXS(self)
#  |      Bound scattering cross section in barn (same as coherentXS()+incoherentXS())
#  |
#  |  to_atomdb_str(self, sep=' ')
#  |      Return data formatted in a string in a format like suitable for the
#  |      the @ATOMDB section of ncmat files, or the atomdb cfg-string parameter
#  |      (see the static method "fmt_atomdb_str" for details).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  fmt_atomdb_str(mass, coh_scat_len, incoh_xs, abs_xs, sep=' ')
#  |      Takes mass value (amu), coherent scattering length (fm), incoherent cross
#  |      section (barn), and absorption cross section @v_n=2200m/s (barn) and return
#  |      data formatted in a string in a format like suitable for the the @ATOMDB
#  |      section of ncmat files, or the atomdb cfg-string parameter. For instance,
#  |      for Si such a data string might look like "28.09u 4.1491fm 0.004b 0.171b" By
#  |      default the four fields are separated by spaces, but the sep parameter can
#  |      be used to change this.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  components
#  |      Get list of all components
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  Component = <class 'NCrystal.core.AtomData.Component'>
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from RCBase:
#  |
#  |  __del__(self)
#  |
#  |  refCount(self)
#  |      Access reference count of wrapped C++ object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from RCBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %% [markdown]
# Here is how to iterate through the entire database:

# %%
for e in NC.iterateAtomDB():
    print(e)
# Out:
# H(cohSL=-3.739fm cohXS=1.75679barn incXS=80.26barn absXS=0.3326barn mass=1.00798amu Z=1)
# H1(cohSL=-3.7406fm cohXS=1.7583barn incXS=80.27barn absXS=0.3326barn mass=1.00783amu Z=1 A=1)
# H2(cohSL=6.671fm cohXS=5.59232barn incXS=2.05barn absXS=0.000519barn mass=2.0141amu Z=1 A=2)
# H3(cohSL=4.792fm cohXS=2.88565barn incXS=0.14barn absXS=0barn mass=3.01605amu Z=1 A=3)
# He(cohSL=3.26548fm cohXS=1.34barn incXS=0barn absXS=0.00747barn mass=4.0026amu Z=2)
# He3(cohSL=5.74fm cohXS=4.14032barn incXS=1.6barn absXS=5333barn mass=3.01603amu Z=2 A=3)
# He4(cohSL=3.26fm cohXS=1.3355barn incXS=0barn absXS=0barn mass=4.0026amu Z=2 A=4)
# Li(cohSL=-1.9fm cohXS=0.453646barn incXS=0.92barn absXS=70.5barn mass=6.94094amu Z=3)
# Li6(cohSL=2fm cohXS=0.502655barn incXS=0.46barn absXS=940barn mass=6.01512amu Z=3 A=6)
# Li7(cohSL=-2.22fm cohXS=0.619321barn incXS=0.78barn absXS=0.0454barn mass=7.016amu Z=3 A=7)
# Be(cohSL=7.79fm cohXS=7.62579barn incXS=0.0018barn absXS=0.0076barn mass=9.01218amu Z=4)
# Be9(cohSL=7.79fm cohXS=7.62579barn incXS=0.0018barn absXS=0.0076barn mass=9.01218amu Z=4 A=9)
# B(cohSL=5.3fm cohXS=3.52989barn incXS=1.7barn absXS=767barn mass=10.81amu Z=5)
# B10(cohSL=-0.1fm cohXS=0.00125664barn incXS=3barn absXS=3835barn mass=10.0129amu Z=5 A=10)
# B11(cohSL=6.65fm cohXS=5.55716barn incXS=0.21barn absXS=0.0055barn mass=11.0093amu Z=5 A=11)
# C(cohSL=6.646fm cohXS=5.55048barn incXS=0.001barn absXS=0.0035barn mass=12.011amu Z=6)
# C12(cohSL=6.6511fm cohXS=5.559barn incXS=0barn absXS=0.00353barn mass=12amu Z=6 A=12)
# C13(cohSL=6.19fm cohXS=4.81494barn incXS=0.034barn absXS=0.00137barn mass=13.0034amu Z=6 A=13)
# N(cohSL=9.36fm cohXS=11.0093barn incXS=0.5barn absXS=1.9barn mass=14.0068amu Z=7)
# N14(cohSL=9.37fm cohXS=11.0329barn incXS=0.5barn absXS=1.91barn mass=14.0031amu Z=7 A=14)
# N15(cohSL=6.44fm cohXS=5.21173barn incXS=5e-05barn absXS=2.4e-05barn mass=15.0001amu Z=7 A=15)
# O(cohSL=5.803fm cohXS=4.2317barn incXS=0.0008barn absXS=0.00019barn mass=15.9993amu Z=8)
# O16(cohSL=5.803fm cohXS=4.2317barn incXS=0barn absXS=0.0001barn mass=15.9949amu Z=8 A=16)
# O17(cohSL=5.78fm cohXS=4.19822barn incXS=0.004barn absXS=0.236barn mass=16.9991amu Z=8 A=17)
# O18(cohSL=5.84fm cohXS=4.28584barn incXS=0barn absXS=0.00016barn mass=17.9992amu Z=8 A=18)
# F(cohSL=5.654fm cohXS=4.01718barn incXS=0.0008barn absXS=0.0096barn mass=18.9984amu Z=9)
# F19(cohSL=5.654fm cohXS=4.01718barn incXS=0.0008barn absXS=0.0096barn mass=18.9984amu Z=9 A=19)
# Ne(cohSL=4.566fm cohXS=2.61988barn incXS=0.008barn absXS=0.039barn mass=20.1794amu Z=10)
# Ne20(cohSL=4.631fm cohXS=2.695barn incXS=0barn absXS=0.036barn mass=19.9924amu Z=10 A=20)
# Ne21(cohSL=6.66fm cohXS=5.57389barn incXS=0.05barn absXS=0.67barn mass=20.9938amu Z=10 A=21)
# Ne22(cohSL=3.87fm cohXS=1.88205barn incXS=0barn absXS=0.046barn mass=21.9914amu Z=10 A=22)
# Na(cohSL=3.63fm cohXS=1.65586barn incXS=1.62barn absXS=0.53barn mass=22.9898amu Z=11)
# Na23(cohSL=3.63fm cohXS=1.65586barn incXS=1.62barn absXS=0.53barn mass=22.9898amu Z=11 A=23)
# Mg(cohSL=5.375fm cohXS=3.6305barn incXS=0.08barn absXS=0.063barn mass=24.3051amu Z=12)
# Mg24(cohSL=5.66fm cohXS=4.02571barn incXS=0barn absXS=0.05barn mass=23.985amu Z=12 A=24)
# Mg25(cohSL=3.62fm cohXS=1.64675barn incXS=0.28barn absXS=0.19barn mass=24.9858amu Z=12 A=25)
# Mg26(cohSL=4.89fm cohXS=3.00488barn incXS=0barn absXS=0.0382barn mass=25.9826amu Z=12 A=26)
# Al(cohSL=3.449fm cohXS=1.49485barn incXS=0.0082barn absXS=0.231barn mass=26.9815amu Z=13)
# Al27(cohSL=3.449fm cohXS=1.49485barn incXS=0.0082barn absXS=0.231barn mass=26.9815amu Z=13 A=27)
# Si(cohSL=4.1491fm cohXS=2.1633barn incXS=0.004barn absXS=0.171barn mass=28.0855amu Z=14)
# Si28(cohSL=4.107fm cohXS=2.11963barn incXS=0barn absXS=0.177barn mass=27.9769amu Z=14 A=28)
# Si29(cohSL=4.7fm cohXS=2.77591barn incXS=0.001barn absXS=0.101barn mass=28.9765amu Z=14 A=29)
# Si30(cohSL=4.58fm cohXS=2.63597barn incXS=0barn absXS=0.107barn mass=29.9738amu Z=14 A=30)
# P(cohSL=5.13fm cohXS=3.30708barn incXS=0.005barn absXS=0.172barn mass=30.9738amu Z=15)
# P31(cohSL=5.13fm cohXS=3.30708barn incXS=0.005barn absXS=0.172barn mass=30.9738amu Z=15 A=31)
# S(cohSL=2.847fm cohXS=1.01856barn incXS=0.007barn absXS=0.53barn mass=32.0644amu Z=16)
# S32(cohSL=2.804fm cohXS=0.98802barn incXS=0barn absXS=0.54barn mass=31.9721amu Z=16 A=32)
# S33(cohSL=4.74fm cohXS=2.82336barn incXS=0.3barn absXS=0.54barn mass=32.9715amu Z=16 A=33)
# S34(cohSL=3.48fm cohXS=1.52184barn incXS=0barn absXS=0.227barn mass=33.9679amu Z=16 A=34)
# S36(cohSL=3fm cohXS=1.13097barn incXS=0barn absXS=0.15barn mass=35.9671amu Z=16 A=36)
# Cl(cohSL=9.577fm cohXS=11.5257barn incXS=5.3barn absXS=33.5barn mass=35.4527amu Z=17)
# Cl35(cohSL=11.65fm cohXS=17.0554barn incXS=4.7barn absXS=44.1barn mass=34.9689amu Z=17 A=35)
# Cl37(cohSL=3.08fm cohXS=1.1921barn incXS=0.001barn absXS=0.433barn mass=36.9659amu Z=17 A=37)
# Ar(cohSL=1.909fm cohXS=0.457954barn incXS=0.225barn absXS=0.675barn mass=39.9477amu Z=18)
# Ar36(cohSL=24.9fm cohXS=77.9128barn incXS=0barn absXS=5.2barn mass=35.9675amu Z=18 A=36)
# Ar38(cohSL=3.5fm cohXS=1.53938barn incXS=0barn absXS=0.8barn mass=37.9627amu Z=18 A=38)
# Ar40(cohSL=1.83fm cohXS=0.420835barn incXS=0barn absXS=0.66barn mass=39.9624amu Z=18 A=40)
# K(cohSL=3.67fm cohXS=1.69255barn incXS=0.27barn absXS=2.1barn mass=39.0983amu Z=19)
# K39(cohSL=3.74fm cohXS=1.75773barn incXS=0.25barn absXS=2.1barn mass=38.9637amu Z=19 A=39)
# K40(cohSL=3fm cohXS=1.13097barn incXS=0.5barn absXS=35barn mass=39.964amu Z=19 A=40)
# K41(cohSL=2.69fm cohXS=0.909315barn incXS=0.3barn absXS=1.46barn mass=40.9618amu Z=19 A=41)
# Ca(cohSL=5.795fm cohXS=4.22004barn incXS=0.05barn absXS=0.43barn mass=40.078amu Z=20)
# Ca40(cohSL=5.90962fm cohXS=4.38864barn incXS=0barn absXS=0.41barn mass=39.9626amu Z=20 A=40)
# Ca42(cohSL=3.36fm cohXS=1.41869barn incXS=0barn absXS=0.68barn mass=41.9586amu Z=20 A=42)
# Ca43(cohSL=-1.56fm cohXS=0.305815barn incXS=0.5barn absXS=6.2barn mass=42.9588amu Z=20 A=43)
# Ca44(cohSL=1.42fm cohXS=0.253388barn incXS=0barn absXS=0.88barn mass=43.9555amu Z=20 A=44)
# Ca46(cohSL=3.6fm cohXS=1.6286barn incXS=0barn absXS=0.74barn mass=45.9537amu Z=20 A=46)
# Ca48(cohSL=0.39fm cohXS=0.0191134barn incXS=0barn absXS=1.09barn mass=47.9525amu Z=20 A=48)
# Sc(cohSL=12.29fm cohXS=18.9808barn incXS=4.5barn absXS=27.5barn mass=44.9559amu Z=21)
# Sc45(cohSL=12.29fm cohXS=18.9808barn incXS=4.5barn absXS=27.5barn mass=44.9559amu Z=21 A=45)
# Ti(cohSL=-3.438fm cohXS=1.48533barn incXS=2.87barn absXS=6.09barn mass=47.8684amu Z=22)
# Ti46(cohSL=4.93fm cohXS=3.05424barn incXS=0barn absXS=0.59barn mass=45.9526amu Z=22 A=46)
# Ti47(cohSL=3.63fm cohXS=1.65586barn incXS=1.5barn absXS=1.7barn mass=46.9518amu Z=22 A=47)
# Ti48(cohSL=-6.08fm cohXS=4.64533barn incXS=0barn absXS=7.84barn mass=47.9479amu Z=22 A=48)
# Ti49(cohSL=1.04fm cohXS=0.135918barn incXS=3.3barn absXS=2.2barn mass=48.9479amu Z=22 A=49)
# Ti50(cohSL=6.18fm cohXS=4.7994barn incXS=0barn absXS=0.179barn mass=49.9448amu Z=22 A=50)
# V(cohSL=-0.3824fm cohXS=0.0183758barn incXS=5.08barn absXS=5.08barn mass=50.9415amu Z=23)
# V50(cohSL=7.6fm cohXS=7.25834barn incXS=0.5barn absXS=60barn mass=49.9472amu Z=23 A=50)
# V51(cohSL=-0.402fm cohXS=0.0203078barn incXS=5.07barn absXS=4.9barn mass=50.944amu Z=23 A=51)
# Cr(cohSL=3.635fm cohXS=1.66042barn incXS=1.83barn absXS=3.05barn mass=51.9959amu Z=24)
# Cr50(cohSL=-4.5fm cohXS=2.54469barn incXS=0barn absXS=15.8barn mass=49.946amu Z=24 A=50)
# Cr52(cohSL=4.92fm cohXS=3.04187barn incXS=0barn absXS=0.76barn mass=51.9405amu Z=24 A=52)
# Cr53(cohSL=-4.2fm cohXS=2.21671barn incXS=5.93barn absXS=18.1barn mass=52.9406amu Z=24 A=53)
# Cr54(cohSL=4.55fm cohXS=2.60155barn incXS=0barn absXS=0.36barn mass=53.9389amu Z=24 A=54)
# Mn(cohSL=-3.73fm cohXS=1.74835barn incXS=0.4barn absXS=13.3barn mass=54.938amu Z=25)
# Mn55(cohSL=-3.73fm cohXS=1.74835barn incXS=0.4barn absXS=13.3barn mass=54.938amu Z=25 A=55)
# Fe(cohSL=9.45fm cohXS=11.2221barn incXS=0.4barn absXS=2.56barn mass=55.8472amu Z=26)
# Fe54(cohSL=4.2fm cohXS=2.21671barn incXS=0barn absXS=2.25barn mass=53.9396amu Z=26 A=54)
# Fe56(cohSL=9.94fm cohXS=12.416barn incXS=0barn absXS=2.59barn mass=55.9349amu Z=26 A=56)
# Fe57(cohSL=2.3fm cohXS=0.664761barn incXS=0.3barn absXS=2.48barn mass=56.9354amu Z=26 A=57)
# Fe58(cohSL=15fm cohXS=28.2743barn incXS=0barn absXS=1.28barn mass=57.9333amu Z=26 A=58)
# Co(cohSL=2.49fm cohXS=0.779128barn incXS=4.8barn absXS=37.18barn mass=58.9332amu Z=27)
# Co59(cohSL=2.49fm cohXS=0.779128barn incXS=4.8barn absXS=37.18barn mass=58.9332amu Z=27 A=59)
# Ni(cohSL=10.3fm cohXS=13.3317barn incXS=5.2barn absXS=4.49barn mass=58.6879amu Z=28)
# Ni58(cohSL=14.4fm cohXS=26.0576barn incXS=0barn absXS=4.6barn mass=57.9353amu Z=28 A=58)
# Ni60(cohSL=2.8fm cohXS=0.985203barn incXS=0barn absXS=2.9barn mass=59.9308amu Z=28 A=60)
# Ni61(cohSL=7.6fm cohXS=7.25834barn incXS=1.9barn absXS=2.5barn mass=60.9311amu Z=28 A=61)
# Ni62(cohSL=-8.7fm cohXS=9.51149barn incXS=0barn absXS=14.5barn mass=61.9283amu Z=28 A=62)
# Ni64(cohSL=-0.37fm cohXS=0.0172034barn incXS=0barn absXS=1.52barn mass=63.928amu Z=28 A=64)
# Cu(cohSL=7.718fm cohXS=7.48548barn incXS=0.55barn absXS=3.78barn mass=63.5456amu Z=29)
# Cu63(cohSL=6.43fm cohXS=5.19555barn incXS=0.006barn absXS=4.5barn mass=62.9296amu Z=29 A=63)
# Cu65(cohSL=10.61fm cohXS=14.1462barn incXS=0.4barn absXS=2.17barn mass=64.9278amu Z=29 A=65)
# Zn(cohSL=5.68fm cohXS=4.05421barn incXS=0.077barn absXS=1.11barn mass=65.3964amu Z=30)
# Zn64(cohSL=5.22fm cohXS=3.42413barn incXS=0barn absXS=0.93barn mass=63.9291amu Z=30 A=64)
# Zn66(cohSL=5.97fm cohXS=4.47877barn incXS=0barn absXS=0.62barn mass=65.926amu Z=30 A=66)
# Zn67(cohSL=7.56fm cohXS=7.18213barn incXS=0.28barn absXS=6.8barn mass=66.9271amu Z=30 A=67)
# Zn68(cohSL=6.03fm cohXS=4.56925barn incXS=0barn absXS=1.1barn mass=67.9248amu Z=30 A=68)
# Zn70(cohSL=6fm cohXS=4.52389barn incXS=0barn absXS=0.092barn mass=69.9253amu Z=30 A=70)
# Ga(cohSL=7.288fm cohXS=6.67462barn incXS=0.16barn absXS=2.75barn mass=69.7232amu Z=31)
# Ga69(cohSL=7.88fm cohXS=7.80301barn incXS=0.091barn absXS=2.18barn mass=68.9256amu Z=31 A=69)
# Ga71(cohSL=6.4fm cohXS=5.14719barn incXS=0.084barn absXS=3.61barn mass=70.9247amu Z=31 A=71)
# Ge(cohSL=8.185fm cohXS=8.41874barn incXS=0.18barn absXS=2.2barn mass=72.6322amu Z=32)
# Ge70(cohSL=10fm cohXS=12.5664barn incXS=0barn absXS=3barn mass=69.9242amu Z=32 A=70)
# Ge72(cohSL=8.51fm cohXS=9.10058barn incXS=0barn absXS=0.8barn mass=71.9221amu Z=32 A=72)
# Ge73(cohSL=5.02fm cohXS=3.16678barn incXS=1.5barn absXS=15.1barn mass=72.9235amu Z=32 A=73)
# Ge74(cohSL=7.58fm cohXS=7.22018barn incXS=0barn absXS=0.4barn mass=73.9212amu Z=32 A=74)
# Ge76(cohSL=8.2fm cohXS=8.44963barn incXS=0barn absXS=0.16barn mass=75.9214amu Z=32 A=76)
# As(cohSL=6.58fm cohXS=5.44079barn incXS=0.06barn absXS=4.5barn mass=74.9216amu Z=33)
# As75(cohSL=6.58fm cohXS=5.44079barn incXS=0.06barn absXS=4.5barn mass=74.9216amu Z=33 A=75)
# Se(cohSL=7.97fm cohXS=7.98227barn incXS=0.32barn absXS=11.7barn mass=78.9933amu Z=34)
# Se74(cohSL=0.8fm cohXS=0.0804248barn incXS=0barn absXS=51.8barn mass=73.9225amu Z=34 A=74)
# Se76(cohSL=12.2fm cohXS=18.7038barn incXS=0barn absXS=85barn mass=75.9192amu Z=34 A=76)
# Se77(cohSL=8.25fm cohXS=8.55299barn incXS=0.05barn absXS=42barn mass=76.9199amu Z=34 A=77)
# Se78(cohSL=8.24fm cohXS=8.53226barn incXS=0barn absXS=0.43barn mass=77.9173amu Z=34 A=78)
# Se80(cohSL=7.48fm cohXS=7.03093barn incXS=0barn absXS=0.61barn mass=79.9165amu Z=34 A=80)
# Se82(cohSL=6.34fm cohXS=5.05113barn incXS=0barn absXS=0.044barn mass=81.9167amu Z=34 A=82)
# Br(cohSL=6.795fm cohXS=5.80215barn incXS=0.1barn absXS=6.9barn mass=79.9035amu Z=35)
# Br79(cohSL=6.8fm cohXS=5.81069barn incXS=0.15barn absXS=11barn mass=78.9183amu Z=35 A=79)
# Br81(cohSL=6.79fm cohXS=5.79361barn incXS=0.05barn absXS=2.7barn mass=80.9163amu Z=35 A=81)
# Kr(cohSL=7.81fm cohXS=7.665barn incXS=0.01barn absXS=25barn mass=83.8amu Z=36)
# Kr86(cohSL=8.1fm cohXS=8.2448barn incXS=0barn absXS=0.003barn mass=85.9106amu Z=36 A=86)
# Rb(cohSL=7.09fm cohXS=6.31688barn incXS=0.5barn absXS=0.38barn mass=85.4677amu Z=37)
# Rb85(cohSL=7.03fm cohXS=6.21041barn incXS=0.5barn absXS=0.48barn mass=84.9118amu Z=37 A=85)
# Rb87(cohSL=7.23fm cohXS=6.56881barn incXS=0.5barn absXS=0.12barn mass=86.9092amu Z=37 A=87)
# Sr(cohSL=7.02fm cohXS=6.19276barn incXS=0.06barn absXS=1.28barn mass=87.6166amu Z=38)
# Sr84(cohSL=7fm cohXS=6.15752barn incXS=0barn absXS=0.87barn mass=83.9134amu Z=38 A=84)
# Sr86(cohSL=5.67fm cohXS=4.03995barn incXS=0barn absXS=1.04barn mass=85.9093amu Z=38 A=86)
# Sr87(cohSL=7.4fm cohXS=6.88134barn incXS=0.5barn absXS=16barn mass=86.9089amu Z=38 A=87)
# Sr88(cohSL=7.15fm cohXS=6.42424barn incXS=0barn absXS=0.058barn mass=87.9056amu Z=38 A=88)
# Y(cohSL=7.75fm cohXS=7.54768barn incXS=0.15barn absXS=1.28barn mass=88.9058amu Z=39)
# Y89(cohSL=7.75fm cohXS=7.54768barn incXS=0.15barn absXS=1.28barn mass=88.9058amu Z=39 A=89)
# Zr(cohSL=7.16fm cohXS=6.44223barn incXS=0.02barn absXS=0.185barn mass=91.219amu Z=40)
# Zr90(cohSL=6.4fm cohXS=5.14719barn incXS=0barn absXS=0.011barn mass=89.9047amu Z=40 A=90)
# Zr91(cohSL=8.7fm cohXS=9.51149barn incXS=0.15barn absXS=1.17barn mass=90.9056amu Z=40 A=91)
# Zr92(cohSL=7.4fm cohXS=6.88134barn incXS=0barn absXS=0.22barn mass=91.905amu Z=40 A=92)
# Zr94(cohSL=8.2fm cohXS=8.44963barn incXS=0barn absXS=0.0499barn mass=93.9063amu Z=40 A=94)
# Zr96(cohSL=5.5fm cohXS=3.80133barn incXS=0barn absXS=0.0229barn mass=95.9083amu Z=40 A=96)
# Nb(cohSL=7.054fm cohXS=6.25289barn incXS=0.0024barn absXS=1.15barn mass=92.9064amu Z=41)
# Nb93(cohSL=7.054fm cohXS=6.25289barn incXS=0.0024barn absXS=1.15barn mass=92.9064amu Z=41 A=93)
# Mo(cohSL=6.715fm cohXS=5.66633barn incXS=0.04barn absXS=2.48barn mass=95.9313amu Z=42)
# Mo92(cohSL=6.91fm cohXS=6.0002barn incXS=0barn absXS=0.019barn mass=91.9068amu Z=42 A=92)
# Mo94(cohSL=6.8fm cohXS=5.81069barn incXS=0barn absXS=0.015barn mass=93.9051amu Z=42 A=94)
# Mo95(cohSL=6.91fm cohXS=6.0002barn incXS=0.5barn absXS=13.1barn mass=94.9058amu Z=42 A=95)
# Mo96(cohSL=6.2fm cohXS=4.83051barn incXS=0barn absXS=0.5barn mass=95.9047amu Z=42 A=96)
# Mo97(cohSL=7.24fm cohXS=6.58699barn incXS=0.5barn absXS=2.5barn mass=96.906amu Z=42 A=97)
# Mo98(cohSL=6.58fm cohXS=5.44079barn incXS=0barn absXS=0.127barn mass=97.9054amu Z=42 A=98)
# Mo100(cohSL=6.73fm cohXS=5.69167barn incXS=0barn absXS=0.4barn mass=99.9075amu Z=42 A=100)
# Tc(cohSL=6.8fm cohXS=5.81069barn incXS=0.5barn absXS=20barn mass=98amu Z=43)
# Ru(cohSL=7.03fm cohXS=6.21041barn incXS=0.4barn absXS=2.56barn mass=101.07amu Z=44)
# Rh(cohSL=5.88fm cohXS=4.34475barn incXS=0.3barn absXS=144.8barn mass=102.905amu Z=45)
# Rh103(cohSL=5.88fm cohXS=4.34475barn incXS=0.3barn absXS=144.8barn mass=102.905amu Z=45 A=103)
# Pd(cohSL=5.91fm cohXS=4.38919barn incXS=0.093barn absXS=6.9barn mass=106.415amu Z=46)
# Pd102(cohSL=7.7fm cohXS=7.4506barn incXS=0barn absXS=3.4barn mass=101.906amu Z=46 A=102)
# Pd104(cohSL=7.7fm cohXS=7.4506barn incXS=0barn absXS=0.6barn mass=103.904amu Z=46 A=104)
# Pd105(cohSL=5.5fm cohXS=3.80133barn incXS=0.8barn absXS=20barn mass=104.905amu Z=46 A=105)
# Pd106(cohSL=6.4fm cohXS=5.14719barn incXS=0barn absXS=0.304barn mass=105.903amu Z=46 A=106)
# Pd108(cohSL=4.1fm cohXS=2.11241barn incXS=0barn absXS=8.55barn mass=107.904amu Z=46 A=108)
# Pd110(cohSL=7.7fm cohXS=7.4506barn incXS=0barn absXS=0.226barn mass=109.905amu Z=46 A=110)
# Ag(cohSL=5.922fm cohXS=4.40704barn incXS=0.58barn absXS=63.3barn mass=107.868amu Z=47)
# Ag107(cohSL=7.555fm cohXS=7.17264barn incXS=0.13barn absXS=37.6barn mass=106.905amu Z=47 A=107)
# Ag109(cohSL=4.165fm cohXS=2.17992barn incXS=0.32barn absXS=91barn mass=108.905amu Z=47 A=109)
# Cd(cohSL=4.87fm cohXS=2.98035barn incXS=3.46barn absXS=2520barn mass=112.41amu Z=48)
# Cd106(cohSL=5fm cohXS=3.14159barn incXS=0barn absXS=1barn mass=105.906amu Z=48 A=106)
# Cd108(cohSL=5.4fm cohXS=3.66435barn incXS=0barn absXS=1.1barn mass=107.904amu Z=48 A=108)
# Cd110(cohSL=5.9fm cohXS=4.37435barn incXS=0barn absXS=11barn mass=109.903amu Z=48 A=110)
# Cd111(cohSL=6.5fm cohXS=5.30929barn incXS=0.3barn absXS=24barn mass=110.904amu Z=48 A=111)
# Cd112(cohSL=6.4fm cohXS=5.14719barn incXS=0barn absXS=2.2barn mass=111.903amu Z=48 A=112)
# Cd113(cohSL=-8fm cohXS=8.04248barn incXS=0.3barn absXS=20600barn mass=112.904amu Z=48 A=113)
# Cd114(cohSL=7.5fm cohXS=7.06858barn incXS=0barn absXS=0.34barn mass=113.903amu Z=48 A=114)
# Cd116(cohSL=6.3fm cohXS=4.98759barn incXS=0barn absXS=0.075barn mass=115.905amu Z=48 A=116)
# In(cohSL=4.065fm cohXS=2.0765barn incXS=0.54barn absXS=193.8barn mass=114.818amu Z=49)
# In113(cohSL=5.39fm cohXS=3.65079barn incXS=3.7e-05barn absXS=12barn mass=112.904amu Z=49 A=113)
# In115(cohSL=4.01fm cohXS=2.02068barn incXS=0.55barn absXS=202barn mass=114.904amu Z=49 A=115)
# Sn(cohSL=6.225fm cohXS=4.86955barn incXS=0.022barn absXS=0.626barn mass=118.685amu Z=50)
# Sn112(cohSL=6fm cohXS=4.52389barn incXS=0barn absXS=1barn mass=111.905amu Z=50 A=112)
# Sn114(cohSL=6.2fm cohXS=4.83051barn incXS=0barn absXS=0.114barn mass=113.903amu Z=50 A=114)
# Sn115(cohSL=6fm cohXS=4.52389barn incXS=0.3barn absXS=30barn mass=114.903amu Z=50 A=115)
# Sn116(cohSL=5.93fm cohXS=4.41895barn incXS=0barn absXS=0.14barn mass=115.902amu Z=50 A=116)
# Sn117(cohSL=6.48fm cohXS=5.27667barn incXS=0.3barn absXS=2.3barn mass=116.903amu Z=50 A=117)
# Sn118(cohSL=6.07fm cohXS=4.63007barn incXS=0barn absXS=0.22barn mass=117.902amu Z=50 A=118)
# Sn119(cohSL=6.12fm cohXS=4.70666barn incXS=0.3barn absXS=2.2barn mass=118.903amu Z=50 A=119)
# Sn120(cohSL=6.49fm cohXS=5.29297barn incXS=0barn absXS=0.14barn mass=119.902amu Z=50 A=120)
# Sn122(cohSL=5.74fm cohXS=4.14032barn incXS=0barn absXS=0.18barn mass=121.903amu Z=50 A=122)
# Sn124(cohSL=5.97fm cohXS=4.47877barn incXS=0barn absXS=0.133barn mass=123.905amu Z=50 A=124)
# Sb(cohSL=5.57fm cohXS=3.8987barn incXS=0.007barn absXS=4.91barn mass=121.758amu Z=51)
# Sb121(cohSL=5.71fm cohXS=4.09715barn incXS=0.0003barn absXS=5.75barn mass=120.904amu Z=51 A=121)
# Sb123(cohSL=5.38fm cohXS=3.63726barn incXS=0.001barn absXS=3.8barn mass=122.904amu Z=51 A=123)
# Te(cohSL=5.8fm cohXS=4.22733barn incXS=0.09barn absXS=4.7barn mass=127.586amu Z=52)
# Te120(cohSL=5.3fm cohXS=3.52989barn incXS=0barn absXS=2.3barn mass=119.904amu Z=52 A=120)
# Te122(cohSL=3.8fm cohXS=1.81458barn incXS=0barn absXS=3.4barn mass=121.903amu Z=52 A=122)
# Te123(cohSL=-0.05fm cohXS=0.000314159barn incXS=0.52barn absXS=418barn mass=122.904amu Z=52 A=123)
# Te124(cohSL=7.96fm cohXS=7.96225barn incXS=0barn absXS=6.8barn mass=123.903amu Z=52 A=124)
# Te125(cohSL=5.02fm cohXS=3.16678barn incXS=0.008barn absXS=1.55barn mass=124.904amu Z=52 A=125)
# Te126(cohSL=5.56fm cohXS=3.88472barn incXS=0barn absXS=1.04barn mass=125.903amu Z=52 A=126)
# Te128(cohSL=5.89fm cohXS=4.35954barn incXS=0barn absXS=0.215barn mass=127.904amu Z=52 A=128)
# Te130(cohSL=6.02fm cohXS=4.5541barn incXS=0barn absXS=0.29barn mass=129.906amu Z=52 A=130)
# I(cohSL=5.28fm cohXS=3.5033barn incXS=0.31barn absXS=6.15barn mass=126.904amu Z=53)
# I127(cohSL=5.28fm cohXS=3.5033barn incXS=0.31barn absXS=6.15barn mass=126.904amu Z=53 A=127)
# Xe(cohSL=4.92fm cohXS=3.04187barn incXS=1.16133barn absXS=23.9barn mass=131.293amu Z=54)
# Cs(cohSL=5.42fm cohXS=3.69155barn incXS=0.21barn absXS=29barn mass=132.905amu Z=55)
# Cs133(cohSL=5.42fm cohXS=3.69155barn incXS=0.21barn absXS=29barn mass=132.905amu Z=55 A=133)
# Ba(cohSL=5.07fm cohXS=3.23017barn incXS=0.15barn absXS=1.1barn mass=137.327amu Z=56)
# Ba130(cohSL=-3.6fm cohXS=1.6286barn incXS=0barn absXS=30barn mass=129.906amu Z=56 A=130)
# Ba132(cohSL=7.8fm cohXS=7.64538barn incXS=0barn absXS=7barn mass=131.905amu Z=56 A=132)
# Ba134(cohSL=5.7fm cohXS=4.08281barn incXS=0barn absXS=2barn mass=133.905amu Z=56 A=134)
# Ba135(cohSL=4.67fm cohXS=2.74059barn incXS=0.5barn absXS=5.8barn mass=134.906amu Z=56 A=135)
# Ba136(cohSL=4.91fm cohXS=3.02951barn incXS=0barn absXS=0.68barn mass=135.905amu Z=56 A=136)
# Ba137(cohSL=6.83fm cohXS=5.86207barn incXS=0.5barn absXS=3.6barn mass=136.906amu Z=56 A=137)
# Ba138(cohSL=4.84fm cohXS=2.94375barn incXS=0barn absXS=0.27barn mass=137.905amu Z=56 A=138)
# La(cohSL=8.24fm cohXS=8.53226barn incXS=1.13barn absXS=8.97barn mass=138.905amu Z=57)
# La138(cohSL=8fm cohXS=8.04248barn incXS=0.5barn absXS=57barn mass=137.907amu Z=57 A=138)
# La139(cohSL=8.24fm cohXS=8.53226barn incXS=1.13barn absXS=8.93barn mass=138.906amu Z=57 A=139)
# Ce(cohSL=4.84fm cohXS=2.94375barn incXS=0.001barn absXS=0.63barn mass=140.115amu Z=58)
# Ce136(cohSL=5.8fm cohXS=4.22733barn incXS=0barn absXS=7.3barn mass=135.907amu Z=58 A=136)
# Ce138(cohSL=6.7fm cohXS=5.64104barn incXS=0barn absXS=1.1barn mass=137.906amu Z=58 A=138)
# Ce140(cohSL=4.84fm cohXS=2.94375barn incXS=0barn absXS=0.57barn mass=139.905amu Z=58 A=140)
# Ce142(cohSL=4.75fm cohXS=2.83529barn incXS=0barn absXS=0.95barn mass=141.909amu Z=58 A=142)
# Pr(cohSL=4.58fm cohXS=2.63597barn incXS=0.015barn absXS=11.5barn mass=140.908amu Z=59)
# Pr141(cohSL=4.58fm cohXS=2.63597barn incXS=0.015barn absXS=11.5barn mass=140.908amu Z=59 A=141)
# Nd(cohSL=7.69fm cohXS=7.43126barn incXS=9.2barn absXS=50.5barn mass=144.241amu Z=60)
# Nd142(cohSL=7.7fm cohXS=7.4506barn incXS=0barn absXS=18.7barn mass=141.908amu Z=60 A=142)
# Nd143(cohSL=14fm cohXS=24.6301barn incXS=55barn absXS=337barn mass=142.91amu Z=60 A=143)
# Nd144(cohSL=2.8fm cohXS=0.985203barn incXS=0barn absXS=3.6barn mass=143.91amu Z=60 A=144)
# Nd145(cohSL=14fm cohXS=24.6301barn incXS=5barn absXS=42barn mass=144.913amu Z=60 A=145)
# Nd146(cohSL=8.7fm cohXS=9.51149barn incXS=0barn absXS=1.4barn mass=145.913amu Z=60 A=146)
# Nd148(cohSL=5.7fm cohXS=4.08281barn incXS=0barn absXS=2.5barn mass=147.917amu Z=60 A=148)
# Nd150(cohSL=5.3fm cohXS=3.52989barn incXS=0barn absXS=1.2barn mass=149.921amu Z=60 A=150)
# Pm(cohSL=12.6fm cohXS=19.9504barn incXS=1.3barn absXS=168.4barn mass=145amu Z=61)
# Sm(cohSL=0.8fm cohXS=0.0804248barn incXS=39barn absXS=5922barn mass=150.35amu Z=62)
# Sm144(cohSL=-3fm cohXS=1.13097barn incXS=0barn absXS=0.7barn mass=143.912amu Z=62 A=144)
# Sm147(cohSL=14fm cohXS=24.6301barn incXS=143barn absXS=57barn mass=146.915amu Z=62 A=147)
# Sm148(cohSL=-3fm cohXS=1.13097barn incXS=0barn absXS=2.4barn mass=147.915amu Z=62 A=148)
# Sm149(cohSL=-19.2fm cohXS=46.3247barn incXS=137barn absXS=42080barn mass=148.917amu Z=62 A=149)
# Sm150(cohSL=14fm cohXS=24.6301barn incXS=0barn absXS=104barn mass=149.917amu Z=62 A=150)
# Sm152(cohSL=-5fm cohXS=3.14159barn incXS=0barn absXS=206barn mass=151.92amu Z=62 A=152)
# Sm154(cohSL=9.3fm cohXS=10.8687barn incXS=0barn absXS=8.4barn mass=153.922amu Z=62 A=154)
# Eu(cohSL=7.22fm cohXS=6.55065barn incXS=2.5barn absXS=4530barn mass=151.965amu Z=63)
# Eu151(cohSL=6.13fm cohXS=4.72205barn incXS=3.1barn absXS=9100barn mass=150.92amu Z=63 A=151)
# Eu153(cohSL=8.22fm cohXS=8.4909barn incXS=1.3barn absXS=312barn mass=152.921amu Z=63 A=153)
# Gd(cohSL=6.5fm cohXS=5.30929barn incXS=151barn absXS=49700barn mass=157.251amu Z=64)
# Gd152(cohSL=10fm cohXS=12.5664barn incXS=0barn absXS=735barn mass=151.92amu Z=64 A=152)
# Gd154(cohSL=10fm cohXS=12.5664barn incXS=0barn absXS=85barn mass=153.921amu Z=64 A=154)
# Gd155(cohSL=6fm cohXS=4.52389barn incXS=25barn absXS=61100barn mass=154.923amu Z=64 A=155)
# Gd156(cohSL=6.3fm cohXS=4.98759barn incXS=0barn absXS=1.5barn mass=155.922amu Z=64 A=156)
# Gd157(cohSL=-1.14fm cohXS=0.163313barn incXS=394barn absXS=259000barn mass=156.924amu Z=64 A=157)
# Gd158(cohSL=9fm cohXS=10.1788barn incXS=0barn absXS=2.2barn mass=157.924amu Z=64 A=158)
# Gd160(cohSL=9.15fm cohXS=10.5209barn incXS=0barn absXS=0.77barn mass=159.927amu Z=64 A=160)
# Tb(cohSL=7.38fm cohXS=6.8442barn incXS=0.004barn absXS=23.4barn mass=158.925amu Z=65)
# Tb159(cohSL=7.38fm cohXS=6.8442barn incXS=0.004barn absXS=23.4barn mass=158.925amu Z=65 A=159)
# Dy(cohSL=16.9fm cohXS=35.8908barn incXS=54.4barn absXS=994barn mass=162.495amu Z=66)
# Dy156(cohSL=6.1fm cohXS=4.67595barn incXS=0barn absXS=33barn mass=155.924amu Z=66 A=156)
# Dy158(cohSL=6fm cohXS=4.52389barn incXS=0barn absXS=43barn mass=157.924amu Z=66 A=158)
# Dy160(cohSL=6.7fm cohXS=5.64104barn incXS=0barn absXS=56barn mass=159.925amu Z=66 A=160)
# Dy161(cohSL=10.3fm cohXS=13.3317barn incXS=3barn absXS=600barn mass=160.927amu Z=66 A=161)
# Dy162(cohSL=-1.4fm cohXS=0.246301barn incXS=0barn absXS=194barn mass=161.927amu Z=66 A=162)
# Dy163(cohSL=5fm cohXS=3.14159barn incXS=0.21barn absXS=124barn mass=162.929amu Z=66 A=163)
# Dy164(cohSL=49.4fm cohXS=306.665barn incXS=0barn absXS=2840barn mass=163.929amu Z=66 A=164)
# Ho(cohSL=8.01fm cohXS=8.0626barn incXS=0.36barn absXS=64.7barn mass=164.93amu Z=67)
# Ho165(cohSL=8.01fm cohXS=8.0626barn incXS=0.36barn absXS=64.7barn mass=164.93amu Z=67 A=165)
# Er(cohSL=7.79fm cohXS=7.62579barn incXS=1.1barn absXS=159barn mass=167.262amu Z=68)
# Er162(cohSL=8.8fm cohXS=9.7314barn incXS=0barn absXS=19barn mass=161.929amu Z=68 A=162)
# Er164(cohSL=8.2fm cohXS=8.44963barn incXS=0barn absXS=13barn mass=163.929amu Z=68 A=164)
# Er166(cohSL=10.6fm cohXS=14.1196barn incXS=0barn absXS=19.6barn mass=165.93amu Z=68 A=166)
# Er167(cohSL=3fm cohXS=1.13097barn incXS=0.13barn absXS=659barn mass=166.932amu Z=68 A=167)
# Er168(cohSL=7.4fm cohXS=6.88134barn incXS=0barn absXS=2.74barn mass=167.932amu Z=68 A=168)
# Er170(cohSL=9.6fm cohXS=11.5812barn incXS=0barn absXS=5.8barn mass=169.935amu Z=68 A=170)
# Tm(cohSL=7.07fm cohXS=6.28129barn incXS=0.1barn absXS=100barn mass=168.934amu Z=69)
# Tm169(cohSL=7.07fm cohXS=6.28129barn incXS=0.1barn absXS=100barn mass=168.934amu Z=69 A=169)
# Yb(cohSL=12.43fm cohXS=19.4157barn incXS=4barn absXS=34.8barn mass=173.033amu Z=70)
# Yb168(cohSL=-4.07fm cohXS=2.08161barn incXS=0barn absXS=2230barn mass=167.934amu Z=70 A=168)
# Yb170(cohSL=6.77fm cohXS=5.75953barn incXS=0barn absXS=11.4barn mass=169.935amu Z=70 A=170)
# Yb171(cohSL=9.66fm cohXS=11.7264barn incXS=3.9barn absXS=48.6barn mass=170.936amu Z=70 A=171)
# Yb172(cohSL=9.43fm cohXS=11.1746barn incXS=0barn absXS=0.8barn mass=171.936amu Z=70 A=172)
# Yb173(cohSL=9.56fm cohXS=11.4849barn incXS=3.5barn absXS=17.1barn mass=172.938amu Z=70 A=173)
# Yb174(cohSL=19.3fm cohXS=46.8085barn incXS=0barn absXS=69.4barn mass=173.939amu Z=70 A=174)
# Yb176(cohSL=8.72fm cohXS=9.55527barn incXS=0barn absXS=2.85barn mass=175.943amu Z=70 A=176)
# Lu(cohSL=7.21fm cohXS=6.53251barn incXS=0.7barn absXS=74barn mass=174.967amu Z=71)
# Lu175(cohSL=7.24fm cohXS=6.58699barn incXS=0.6barn absXS=21barn mass=174.941amu Z=71 A=175)
# Lu176(cohSL=6.1fm cohXS=4.67595barn incXS=1.2barn absXS=2065barn mass=175.943amu Z=71 A=176)
# Hf(cohSL=7.7fm cohXS=7.4506barn incXS=2.6barn absXS=104.1barn mass=178.488amu Z=72)
# Hf174(cohSL=10.9fm cohXS=14.9301barn incXS=0barn absXS=561barn mass=173.94amu Z=72 A=174)
# Hf176(cohSL=6.61fm cohXS=5.49051barn incXS=0barn absXS=23.5barn mass=175.941amu Z=72 A=176)
# Hf177(cohSL=0.8fm cohXS=0.0804248barn incXS=0.1barn absXS=373barn mass=176.943amu Z=72 A=177)
# Hf178(cohSL=5.9fm cohXS=4.37435barn incXS=0barn absXS=84barn mass=177.944amu Z=72 A=178)
# Hf179(cohSL=7.46fm cohXS=6.99339barn incXS=0.14barn absXS=41barn mass=178.946amu Z=72 A=179)
# Hf180(cohSL=13.2fm cohXS=21.8956barn incXS=0barn absXS=13.04barn mass=179.947amu Z=72 A=180)
# Ta(cohSL=6.91fm cohXS=6.0002barn incXS=0.01barn absXS=20.6barn mass=180.948amu Z=73)
# Ta180(cohSL=7fm cohXS=6.15752barn incXS=0.5barn absXS=563barn mass=179.947amu Z=73 A=180)
# Ta181(cohSL=6.91fm cohXS=6.0002barn incXS=0.011barn absXS=20.5barn mass=180.948amu Z=73 A=181)
# W(cohSL=4.86fm cohXS=2.96813barn incXS=1.63barn absXS=18.3barn mass=183.85amu Z=74)
# W180(cohSL=5fm cohXS=3.14159barn incXS=0barn absXS=30barn mass=179.947amu Z=74 A=180)
# W182(cohSL=6.97fm cohXS=6.10486barn incXS=0barn absXS=20.7barn mass=181.948amu Z=74 A=182)
# W183(cohSL=6.53fm cohXS=5.35841barn incXS=0.3barn absXS=10.1barn mass=182.95amu Z=74 A=183)
# W184(cohSL=7.48fm cohXS=7.03093barn incXS=0barn absXS=1.7barn mass=183.951amu Z=74 A=184)
# W186(cohSL=-0.72fm cohXS=0.0651441barn incXS=0barn absXS=37.9barn mass=185.954amu Z=74 A=186)
# Re(cohSL=9.2fm cohXS=10.6362barn incXS=0.9barn absXS=89.7barn mass=186.207amu Z=75)
# Re185(cohSL=9fm cohXS=10.1788barn incXS=0.5barn absXS=112barn mass=184.953amu Z=75 A=185)
# Re187(cohSL=9.3fm cohXS=10.8687barn incXS=1barn absXS=76.4barn mass=186.956amu Z=75 A=187)
# Os(cohSL=10.7fm cohXS=14.3872barn incXS=0.3barn absXS=16barn mass=190.24amu Z=76)
# Os184(cohSL=10fm cohXS=12.5664barn incXS=0barn absXS=3000barn mass=183.952amu Z=76 A=184)
# Os186(cohSL=11.6fm cohXS=16.9093barn incXS=0barn absXS=80barn mass=185.954amu Z=76 A=186)
# Os187(cohSL=10fm cohXS=12.5664barn incXS=0.3barn absXS=320barn mass=186.956amu Z=76 A=187)
# Os188(cohSL=7.6fm cohXS=7.25834barn incXS=0barn absXS=4.7barn mass=187.956amu Z=76 A=188)
# Os189(cohSL=10.7fm cohXS=14.3872barn incXS=0.5barn absXS=25barn mass=188.958amu Z=76 A=189)
# Os190(cohSL=11fm cohXS=15.2053barn incXS=0barn absXS=13.1barn mass=189.958amu Z=76 A=190)
# Os192(cohSL=11.5fm cohXS=16.619barn incXS=0barn absXS=2barn mass=191.961amu Z=76 A=192)
# Ir(cohSL=10.6fm cohXS=14.1196barn incXS=0barn absXS=425barn mass=192.216amu Z=77)
# Pt(cohSL=9.6fm cohXS=11.5812barn incXS=0.13barn absXS=10.3barn mass=195.08amu Z=78)
# Pt190(cohSL=9fm cohXS=10.1788barn incXS=0barn absXS=152barn mass=189.96amu Z=78 A=190)
# Pt192(cohSL=9.9fm cohXS=12.3163barn incXS=0barn absXS=10barn mass=191.961amu Z=78 A=192)
# Pt194(cohSL=10.55fm cohXS=13.9867barn incXS=0barn absXS=1.44barn mass=193.963amu Z=78 A=194)
# Pt195(cohSL=8.83fm cohXS=9.79786barn incXS=0.13barn absXS=27.5barn mass=194.965amu Z=78 A=195)
# Pt196(cohSL=9.89fm cohXS=12.2914barn incXS=0barn absXS=0.72barn mass=195.965amu Z=78 A=196)
# Pt198(cohSL=7.8fm cohXS=7.64538barn incXS=0barn absXS=3.66barn mass=197.968amu Z=78 A=198)
# Au(cohSL=7.63fm cohXS=7.31575barn incXS=0.43barn absXS=98.65barn mass=196.967amu Z=79)
# Au197(cohSL=7.63fm cohXS=7.31575barn incXS=0.43barn absXS=98.65barn mass=196.967amu Z=79 A=197)
# Hg(cohSL=12.692fm cohXS=20.2428barn incXS=6.6barn absXS=372.3barn mass=200.585amu Z=80)
# Hg196(cohSL=30.3fm cohXS=115.371barn incXS=0barn absXS=3080barn mass=195.966amu Z=80 A=196)
# Hg199(cohSL=16.9fm cohXS=35.8908barn incXS=30barn absXS=2150barn mass=198.968amu Z=80 A=199)
# Tl(cohSL=8.776fm cohXS=9.67839barn incXS=0.21barn absXS=3.43barn mass=204.383amu Z=81)
# Tl203(cohSL=6.99fm cohXS=6.13994barn incXS=0.14barn absXS=11.4barn mass=202.972amu Z=81 A=203)
# Tl205(cohSL=9.52fm cohXS=11.389barn incXS=0.007barn absXS=0.104barn mass=204.974amu Z=81 A=205)
# Pb(cohSL=9.405fm cohXS=11.1155barn incXS=0.003barn absXS=0.171barn mass=207.217amu Z=82)
# Pb204(cohSL=9.9fm cohXS=12.3163barn incXS=0barn absXS=0.65barn mass=203.973amu Z=82 A=204)
# Pb206(cohSL=9.22fm cohXS=10.6825barn incXS=0barn absXS=0.03barn mass=205.974amu Z=82 A=206)
# Pb207(cohSL=9.28fm cohXS=10.822barn incXS=0.002barn absXS=0.699barn mass=206.976amu Z=82 A=207)
# Pb208(cohSL=9.5fm cohXS=11.3411barn incXS=0barn absXS=0.00048barn mass=207.977amu Z=82 A=208)
# Bi(cohSL=8.532fm cohXS=9.14769barn incXS=0.0084barn absXS=0.0338barn mass=208.98amu Z=83)
# Bi209(cohSL=8.532fm cohXS=9.14769barn incXS=0.0084barn absXS=0.0338barn mass=208.98amu Z=83 A=209)
# Ra(cohSL=10fm cohXS=12.5664barn incXS=0barn absXS=12.8barn mass=226amu Z=88)
# Th(cohSL=10.31fm cohXS=13.3576barn incXS=0barn absXS=7.37barn mass=232.038amu Z=90)
# Th232(cohSL=10.31fm cohXS=13.3576barn incXS=0barn absXS=7.37barn mass=232.038amu Z=90 A=232)
# Pa(cohSL=9.1fm cohXS=10.4062barn incXS=0.1barn absXS=200.6barn mass=231.036amu Z=91)
# U(cohSL=8.417fm cohXS=8.90276barn incXS=0.005barn absXS=7.57barn mass=238.029amu Z=92)
# U233(cohSL=10.1fm cohXS=12.819barn incXS=0.1barn absXS=574.7barn mass=233.04amu Z=92 A=233)
# U234(cohSL=12.4fm cohXS=19.3221barn incXS=0barn absXS=100.1barn mass=234.041amu Z=92 A=234)
# U235(cohSL=10.47fm cohXS=13.7754barn incXS=0.2barn absXS=680.9barn mass=235.044amu Z=92 A=235)
# U238(cohSL=8.402fm cohXS=8.87105barn incXS=0barn absXS=2.68barn mass=238.051amu Z=92 A=238)

# %% [markdown]
# It is always possible to override some of these values for a particular material, or even to provide values for elements or isotopes that might be missing. This can be done either in the `@ATOMDB` section of NCMAT data (cf. https://github.com/mctools/ncrystal/wiki/NCMAT-format), or through the `atomdb` cfg-string variable (cf. https://github.com/mctools/ncrystal/wiki/CfgRefDoc). We will return to this subject when discussing the `NCMATComposer` in another Notebook.

# %% [markdown]
# ### Gas mixtures and other on-demand NCMAT data for simple materials
# As a nice side-effect from having the flexible data source infrastructure, NCrystal also contains several plugins providing "quick materials": Materials so simple, that they can be expressed in a "filename". Rather than locating a real file, the plugin handling the request will analyse the intent expressed in the "filename", and dynamically compose the appropriate NCMAT data to reflect this request. The best example of this is the `"gasmix"` plugin, handling gas mixtures:
#
# * `"gasmix::0.72xCO2+0.28xAr/massfractions/1.5atm/250K"`
# * `"gasmix::0.7xCO2+0.3xAr/0.001relhumidity"`
# * `"gasmix::0.7xCO2+0.3xAr/1.5atm/250K"`
# * `"gasmix::BF3/2atm/25C/B_is_0.95_B10_0.05_B11"`
# * `"gasmix::CO2"`
# * `"gasmix::He/1.64kgm3"`
# * `"gasmix::He/10bar"`
# * `"gasmix::air"`
# * `"gasmix::air/-10C/0.8atm/0.30relhumidity"`
#
# Hopefully, you can guess what each line above would give you! The only thing to be aware about though, is that unless `/massfractions` are explicitly requested as in the first example above, the mixture is going to be by-volume (or by-mole of molecules which is the same thing in this case).
#
# You can of course always check the result by looking at the NCMAT data created in response to the request (cf. https://github.com/mctools/ncrystal/wiki/NCMAT-format). You can also load and inspect the material. First the NCMAT data:

# %%
print(NC.createTextData("gasmix::0.7xCO2+0.3xAr/25C/0.001relhumidity").rawData)
# Out:
# NCMAT v7
# #
# # Automatically generated NCMAT data for gas mixture
# #
# # Request: "gasmix::0.7xCO2+0.3xAr/0.001relhumidity/25C"
# #
# # Resulting gas parameters:
# #
# #  T   = 298.15K
# #  P   = 101325Pa
# #  Rho = 1.7490115990149013kg/m^3
# #
# @STATEOFMATTER
#   gas
# @TEMPERATURE
#   298.15
# @DENSITY
#   1.7490115990149013 kg_per_m3
# @DYNINFO
#   element  H
#   fraction 2.6070608092054429e-05
#   type     freegas
# @DYNINFO
#   element  Ar
#   fraction 0.12499511176098276
#   type     freegas
# @DYNINFO
#   element  C
#   fraction 0.29165526077562637
#   type     freegas
# @DYNINFO
#   element  O
#   fraction 0.5833235568552988
#   type     freegas

# %% [markdown]
# Or look at the loaded `Info` object:

# %%
NC.createInfo("gasmix::0.7xCO2+0.3xAr/25C/0.001relhumidity").dump()
# Out:
# ----------------------------------------------------------------------------------------------------
# ------------------------------------   NCrystal Material Info   ------------------------------------
# ----------------------------------------------------------------------------------------------------
# Data source: gasmix::0.7xCO2+0.3xAr/25C/0.001relhumidity
# ----------------------------------------------------------------------------------------------------
# Density : 0.00174901 g/cm3, 5.90763e-05 atoms/Aa^3
# ----------------------------------------------------------------------------------------------------
# Composition (by mole): 0.00260706% H 29.1655% C 58.3324% O 12.4995% Ar
# ----------------------------------------------------------------------------------------------------
# Composition (by mass): 0.000147391% H 19.6481% C 52.3456% O 28.0062% Ar
# ----------------------------------------------------------------------------------------------------
# Atom data:
#    H  = H(cohSL=-3.739fm cohXS=1.75679barn incXS=80.26barn absXS=0.3326barn mass=1.00798u Z=1)
#    C  = C(cohSL=6.646fm cohXS=5.55048barn incXS=0.001barn absXS=0.0035barn mass=12.011u Z=6)
#    O  = O(cohSL=5.803fm cohXS=4.2317barn incXS=0.0008barn absXS=0.00019barn mass=15.9993u Z=8)
#    Ar = Ar(cohSL=1.909fm cohXS=0.457954barn incXS=0.225barn absXS=0.675barn mass=39.9477u Z=18)
# ----------------------------------------------------------------------------------------------------
# Averaged quantities:
#    Atomic mass               : 17.8291u
#    Absorption XS at 2200m/s  : 0.085512 barn
#    Free scattering XS        : 3.64447 barn
#    Scattering length density : 0.00328576 10^-6/Aa^2
# ----------------------------------------------------------------------------------------------------
# Temperature : 298.15 kelvin
# ----------------------------------------------------------------------------------------------------
# State of matter: Gas
# ----------------------------------------------------------------------------------------------------
# Dynamic info for H (0.00260706%):
#    type: freegas
# Dynamic info for C (29.1655%):
#    type: freegas
# Dynamic info for O (58.3324%):
#    type: freegas
# Dynamic info for Ar (12.4995%):
#    type: freegas
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Or plot the cross sections:

# %%
ncplot.plot_xsect("gasmix::0.7xCO2+0.3xAr/25C/0.001relhumidity")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# One thing you might have noticed about the dumped NCMAT data above is the section:
# ```
# @TEMPERATURE
#   298.15
# ```
# It means that NCrystal will refuse to let the user change the temperature of this material further, which is a safeguard against someone trying to change the temperature like this (which would give a material with the wrong density!):

# %%
try:
    NC.load("gasmix::0.7xCO2+0.3xAr/25C/0.001relhumidity;temp=10K")
except NC.NCBadInput as e:
    print("NCBadInput ERROR: %s"%e)
# Out:
# NCBadInput ERROR: 0.7xCO2+0.3xAr/0.001relhumidity/25C requested temperature (10K) is incompatible with temperature (298.15K) at which input data is valid.

# %% [markdown]
# The right way to modify the temperature is inside the "filename" part (changing `25C`->`10K`):

# %%
NC.load("gasmix::0.7xCO2+0.3xAr/10K/0.001relhumidity")
# Out:
# LoadedMaterial(Info=<NCrystal.core.Info object at 0x76b4d4b1d4f0>, Scatter=<NCrystal.core.Scatter object at 0x76b4ea528500>, Absorption=<NCrystal.core.Absorption object at 0x76b4d68ab9e0>)

# %% [markdown]
# Two other "quick factories" exists, which can be useful in the case where a non-gaseous material needs to be included in a simulation, but where the exact material *structure* is not important (or, not known!):
#
# * `"freegas::Ar/2.5e-5perAa3"`
# * `"freegas::CF4/3.72kgm3"`
# * `"freegas::CO2/1.98kgm3"`
# * `"freegas::He/0.17kgm3/He_is_He3"`
# * `"solid::Al2O3/4gcm3"`
# * `"solid::B4C/2.52gcm3/B_is_0.95_B10_0.05_B11"`
# * `"solid::CH2/1gcm3"`
# * `"solid::Gd2O3/7.07gcm3"`
# * `"solid::Al2O3/4gcm3/TDebye750K_Al/TDebye1000K_O"`
# * `"solid::Al2O3/4gcm3/TDebye900K"`

# %% [markdown]
# These materials will get the density and composition which can be inferred from the strings. In the case of `freegas::` materials, all atoms will be modelled as independent free gas atoms. In a way this is no different to how materials are mostly modelled in OpenMC/Geant/MCNP/..., but it is useful to have such simple materials in NCrystal as well - not the least for when NCrystal is used standalone or in applications like McStas where there is otherwise no universal concept of a "base material".
#
# The `solid::` materials are very similar, but they differ in that their simplistic dynamics will be appropriate for bound atoms rather than free atoms. Such a feature was easy enough to add in NCrystal, since we can generate all dynamics of an amorphous material based on a 1D phonon DOS curve, and we simply use a simplistic phonon DOS curve as input (the Debye model).
